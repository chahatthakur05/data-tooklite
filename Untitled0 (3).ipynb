# %% [markdown]
# ### `**DATA TOOKLITE**`
#
# 1. What is NumPy, and why is it widely used in Python?
# NumPy (Numerical Python) is a library for efficient numerical computation. It's widely used for handling arrays, matrices, and performing mathematical operations due to its speed and efficiency.
#
# 2. How does broadcasting work in NumPy?
# Broadcasting in NumPy allows you to perform operations on arrays of different shapes by aligning them based on certain rules, making element-wise operations possible without needing explicit loops.
#
# 3. What is a Pandas DataFrame?
# A Pandas DataFrame is a 2-dimensional labeled data structure with columns of potentially different types, similar to a spreadsheet or SQL table.
#
# 4. Explain the use of the groupby() method in Pandas.
# The groupby() method groups data by some criteria (like a column value), allowing you to perform operations like sum, mean, etc., on those groups.
#
# 5. Why is Seaborn preferred for statistical visualizations?
# Seaborn is preferred for statistical visualizations because it provides high-level functions for attractive and informative plots, built on top of Matplotlib.
#
# 6. What are the differences between NumPy arrays and Python lists?
# NumPy arrays are more efficient for numerical operations, support vectorized operations, and are homogeneous. Python lists are heterogeneous and more flexible but slower for numerical computations.
#
# 7. What is a heatmap, and when should it be used?
# A heatmap is a 2D data visualization where values are represented by colors. Use it to show relationships between two variables or for correlation matrices.
#
# 8. What does the term “vectorized operation” mean in NumPy?
# Vectorized operations in NumPy mean performing operations on entire arrays without explicit loops, making computations faster.
#
# 9. How does Matplotlib differ from Plotly?
# Matplotlib is a static plotting library, while Plotly is interactive, allowing for hover effects, zooming, etc.
#
# 10. What is the significance of hierarchical indexing in Pandas?
# Hierarchical indexing (MultiIndex) in Pandas allows you to work with higher-dimensional data in a 2D DataFrame.
#
# 11. What is the role of Seaborn's pairplot() function?
# Seaborn's pairplot() shows pairwise relationships in a dataset, useful for exploring correlations.
#
# 12. What is the purpose of the describe() function in Pandas?
# The describe() function in Pandas generates descriptive statistics for numeric columns in a DataFrame.
#
# 13. Why is handling missing data important in Pandas?
# Handling missing data is important to ensure accurate analysis and prevent errors or biases in results.
#
# 14. What are the benefits of using Plotly for data visualization?
# Plotly's benefits include interactive plots, hover effects, zooming, and sharing interactive plots online.
#
#  15. How does NumPy handle multidimensional arrays?
# NumPy handles multidimensional arrays using the ndarray object. You can create arrays with multiple dimensions, and NumPy provides various methods for indexing, slicing, and performing operations on these arrays.
#
# 16. What is the role of Bokeh in data visualization?
# Bokeh is a Python library used for creating interactive visualizations in web browsers. It provides elegant, concise construction of versatile graphics and allows users to interact with the plots.
#
# 17. Explain the difference between apply() and map() in Pandas.
# In Pandas, apply() is used to apply a function along an axis of the DataFrame or on a Series. map() is used to map values of a Series according to an input mapping or function. apply() is more flexible and can handle complex operations, while map() is typically used for element-wise transformations.
#
# 18. What are some advanced features of NumPy?
# Some advanced features of NumPy include:
# - Broadcasting: Allows operations on arrays of different shapes.
# - Vectorized operations: For efficient element-wise operations.
# - Linear algebra functions: Like dot(), inv(), etc.
#
# 19. How does Pandas simplify time series analysis?
# Pandas simplifies time series analysis with its DatetimeIndex and functions like resample(), rolling(), and date range generation. It allows for easy handling of time-based data.
#
# 20. What is the role of a pivot table in Pandas?
# In Pandas, a pivot table is used to reshape and aggregate data. It allows you to transform and summarize data based on some criteria.
#
#  21. Why is NumPy's array slicing faster than Python's list slicing?
# NumPy's array slicing is faster because NumPy arrays are stored in contiguous memory blocks, allowing for more efficient operations. Also, NumPy operations are vectorized and optimized in C.
#
# 22. What are some common use cases for Seaborn?
# Common use cases for Seaborn include:
# - Visualizing distributions of data.
# - Plotting categorical data.
# - Creating regression plots.
# - Making heatmaps for correlation matrices.

# %%
#1
using .sum(axis=1).
import numpy as np
arr = np.array([[1, 2], [3, 4]])
row_sums = arr.sum(axis=1)
print(row_sums)
# Out:
#   File "/tmp/ipython-input-3421715110.py", line 2
#     using .sum(axis=1).
#                        ^
# SyntaxError: invalid syntax

# %%
#2
import pandas as pd
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
mean_of_A = df['A'].mean()
print(mean_of_A)
# Out:
# 2.0

# %%
#3
import matplotlib.pyplot as plt
x = [1, 2, 3]
y = [4, 5, 6]
plt.scatter(x, y)
plt.show()

# %%
#4
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
#5
import plotly.express as px
df = pd.DataFrame({'Category': ['A', 'B', 'C'], 'Values': [10, 20, 30]})
fig = px.bar(df, x='Category', y='Values')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#6
df = pd.DataFrame({'A': [1, 2, 3]})
df['B'] = df['A'] * 2
print(df)
# Out:
#    A  B
# 0  1  2
# 1  2  4
# 2  3  6

# %%
#7
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])
result = arr1 * arr2
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4270740797.py in <cell line: 0>()
#       1 #7
# ----> 2 arr1 = np.array([1, 2, 3])
#       3 arr2 = np.array([4, 5, 6])
#       4 result = arr1 * arr2
#       5 print(result)
#
# NameError: name 'np' is not defined

# %%
#8
x = [1, 2, 3]
y1 = [4, 5, 6]
y2 = [7, 8, 9]
plt.plot(x, y1, label='Line 1')
plt.plot(x, y2, label='Line 2')
plt.legend()
plt.show()

# %%
#9
df = pd.DataFrame({'A': [1, 2, 3]})
filtered_df = df[df['A'] > 2]
print(filtered_df)
# Out:
#    A
# 2  3

# %%
#10
import seaborn as sns
import matplotlib.pyplot as plt
data = [1, 2, 2, 3, 3, 3]
sns.histplot(data)
plt.show()

# %%
#11
arr1 = np.array([[1, 2], [3, 4]])
arr2 = np.array([[5, 6], [7, 8]])
result = np.dot(arr1, arr2)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3479302082.py in <cell line: 0>()
#       1 #11
# ----> 2 arr1 = np.array([[1, 2], [3, 4]])
#       3 arr2 = np.array([[5, 6], [7, 8]])
#       4 result = np.dot(arr1, arr2)
#       5 print(result)
#
# NameError: name 'np' is not defined

# %%
#12
df = pd.read_csv('filename.csv')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-667676289.py in <cell line: 0>()
#       1 #12
# ----> 2 df = pd.read_csv('filename.csv')
#       3 print(df.head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#13
import plotly.graph_objects as go
x = [1, 2, 3]
y = [4, 5, 6]
z = [7, 8, 9]
fig = go.Figure(data=[go.Scatter3d(x=x,y=y, z=z, mode='markers')])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
